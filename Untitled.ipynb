# %%
import nltk
import numpy as np
import datetime
import pandas as pd
import matplotlib.pyplot as plt
import os
import seaborn as sns

# %%
airports = pd.read_csv('../AML_group24/airports.csv', sep=',')
airlines = pd.read_csv('../AML_group24/airlines.csv')
flights_test = pd.read_csv('../AML_group24/flights_test.csv')
flights_train = pd.read_csv('../AML_group24/flights_train.csv')

# %%
# display number of null values for each column if exist 
def values_null(df_data):
    if df_data.isnull().values.any():
        display(df_data.isnull().sum())
    else:
        display("Null values")

# convert year, month, day to date
def retrieve_date(values):
    return datetime.datetime(year=values['YEAR'], month=values['MONTH'], day=values['DAY'])

def delayed_or_not(row):
    delays = 0
    on_time = 0
    if row['ARRIVAL_DELAY'] != 0:
        return 1
    else:
        return 0

# %%
flights_train['date'] = flights_train.apply(retrieve_date,axis=1)
flights_train['date'] = pd.to_datetime(flights_train['date'])
# flights_train = flights_train.drop(['id', 'YEAR', 'MONTH', 'DAY', 'DAY_OF_WEEK', 'FLIGHT_NUMBER', 'TAIL_NUMBER'], axis=1)
# cleand_date = cleaned.day_name('date', axis=1)
flights_train['Day'] = flights_train['date'].dt.day_name()
display(flights_train)
# Out:
#               id  YEAR  MONTH  DAY  DAY_OF_WEEK AIRLINE  FLIGHT_NUMBER  \
# 0              0  2015      1    1            4      AS             98
# 1              1  2015      1    1            4      AA           2336
# 2              2  2015      1    1            4      US            840
# 3              3  2015      1    1            4      AA            258
# 4              4  2015      1    1            4      AS            135
# ...          ...   ...    ...  ...          ...     ...            ...
# 2818548  2818548  2015      6   30            2      UA           1180
# 2818549  2818549  2015      6   30            2      UA           1192
# 2818550  2818550  2015      6   30            2      UA           1480
# 2818551  2818551  2015      6   30            2      UA           1637
# 2818552  2818552  2015      6   30            2      UA           1903
#
#         TAIL_NUMBER ORIGIN_AIRPORT DESTINATION_AIRPORT  SCHEDULED_DEPARTURE  \
# 0            N407AS            ANC                 SEA                    5
# 1            N3KUAA            LAX                 PBI                   10
# 2            N171US            SFO                 CLT                   20
# 3            N3HYAA            LAX                 MIA                   20
# 4            N527AS            SEA                 ANC                   25
# ...             ...            ...                 ...                  ...
# 2818548      N65832            LAX                 ORD                 2359
# 2818549      N69839            LAX                 IAH                 2359
# 2818550      N37298            PDX                 IAH                 2359
# 2818551      N35260            SEA                 IAH                 2359
# 2818552      N35271            IAH                 SJU                 2359
#
#          DEPARTURE_TIME  TAXI_OUT  WHEELS_OFF  SCHEDULED_TIME  DISTANCE  \
# 0                2354.0      21.0        15.0           205.0      1448
# 1                   2.0      12.0        14.0           280.0      2330
# 2                  18.0      16.0        34.0           286.0      2296
# 3                  15.0      15.0        30.0           285.0      2342
# 4                  24.0      11.0        35.0           235.0      1448
# ...                 ...       ...         ...             ...       ...
# 2818548          2358.0      11.0         9.0           241.0      1744
# 2818549           129.0      11.0       140.0           201.0      1379
# 2818550           152.0       8.0       200.0           249.0      1825
# 2818551            12.0      12.0        24.0           250.0      1874
# 2818552             7.0      14.0        21.0           275.0      2007
#
#          SCHEDULED_ARRIVAL  ARRIVAL_DELAY       date       Day
# 0                      430          -22.0 2015-01-01  Thursday
# 1                      750           -9.0 2015-01-01  Thursday
# 2                      806            5.0 2015-01-01  Thursday
# 3                      805           -9.0 2015-01-01  Thursday
# 4                      320          -21.0 2015-01-01  Thursday
# ...                    ...            ...        ...       ...
# 2818548                600           -8.0 2015-06-30   Tuesday
# 2818549                520           79.0 2015-06-30   Tuesday
# 2818550                608          107.0 2015-06-30   Tuesday
# 2818551                609            9.0 2015-06-30   Tuesday
# 2818552                534           -8.0 2015-06-30   Tuesday
#
# [2818553 rows x 20 columns]

# %%
flights_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2818553 entries, 0 to 2818552
# Data columns (total 20 columns):
#  #   Column               Dtype
# ---  ------               -----
#  0   id                   int64
#  1   YEAR                 int64
#  2   MONTH                int64
#  3   DAY                  int64
#  4   DAY_OF_WEEK          int64
#  5   AIRLINE              object
#  6   FLIGHT_NUMBER        int64
#  7   TAIL_NUMBER          object
#  8   ORIGIN_AIRPORT       object
#  9   DESTINATION_AIRPORT  object
#  10  SCHEDULED_DEPARTURE  int64
#  11  DEPARTURE_TIME       float64
#  12  TAXI_OUT             float64
#  13  WHEELS_OFF           float64
#  14  SCHEDULED_TIME       float64
#  15  DISTANCE             int64
#  16  SCHEDULED_ARRIVAL    int64
#  17  ARRIVAL_DELAY        float64
#  18  date                 datetime64[ns]
#  19  Day                  object
# dtypes: datetime64[ns](1), float64(5), int64(9), object(5)
# memory usage: 430.1+ MB

# %%
sns.jointplot(data=flights_train, x="SCHEDULED_DEPARTURE", y="DEPARTURE_TIME")

# %%
corr = train_data.corr(method='pearson')
sns.heatmap(corr)
# Out:
# <AxesSubplot:>

# %%
corr
# Out:
#                      SCHEDULED_DEPARTURE  DEPARTURE_TIME  TAXI_OUT  \
# SCHEDULED_DEPARTURE             1.000000        0.964189 -0.008020
# DEPARTURE_TIME                  0.964189        1.000000  0.000728
# TAXI_OUT                       -0.008020        0.000728  1.000000
# WHEELS_OFF                      0.938907        0.972747  0.026827
# SCHEDULED_TIME                 -0.016488       -0.020876  0.111012
# DISTANCE                       -0.008196       -0.015219  0.069282
# SCHEDULED_ARRIVAL               0.718819        0.721558  0.011364
# ARRIVAL_DELAY                   0.103083        0.164384  0.238806
#
#                      WHEELS_OFF  SCHEDULED_TIME  DISTANCE  SCHEDULED_ARRIVAL  \
# SCHEDULED_DEPARTURE    0.938907       -0.016488 -0.008196           0.718819
# DEPARTURE_TIME         0.972747       -0.020876 -0.015219           0.721558
# TAXI_OUT               0.026827        0.111012  0.069282           0.011364
# WHEELS_OFF             1.000000       -0.027731 -0.025878           0.731761
# SCHEDULED_TIME        -0.027731        1.000000  0.983078           0.034685
# DISTANCE              -0.025878        0.983078  1.000000           0.031840
# SCHEDULED_ARRIVAL      0.731761        0.034685  0.031840           1.000000
# ARRIVAL_DELAY          0.160181       -0.027254 -0.023849           0.092671
#
#                      ARRIVAL_DELAY
# SCHEDULED_DEPARTURE       0.103083
# DEPARTURE_TIME            0.164384
# TAXI_OUT                  0.238806
# WHEELS_OFF                0.160181
# SCHEDULED_TIME           -0.027254
# DISTANCE                 -0.023849
# SCHEDULED_ARRIVAL         0.092671
# ARRIVAL_DELAY             1.000000

# %%
train_data = flights_train.drop(['id', 'YEAR', 'MONTH', 'DAY', 'DAY_OF_WEEK', 'FLIGHT_NUMBER', 'TAIL_NUMBER'], axis=1)
cleand_date = train_data.day_name('date', axis=1)
